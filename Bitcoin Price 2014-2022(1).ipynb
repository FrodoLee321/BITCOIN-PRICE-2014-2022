# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('bitcoindata.csv')
print (data.shape)
data.info()
# Out:
# (2747, 7)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2747 entries, 0 to 2746
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2747 non-null   object
#  1   Open       2747 non-null   float64
#  2   High       2747 non-null   float64
#  3   Low        2747 non-null   float64
#  4   Close      2747 non-null   float64
#  5   Adj Close  2747 non-null   float64
#  6   Volume     2747 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 150.4+ KB

# %%
data.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2014-09-17  465.864014  468.174011  452.421997  457.334015  457.334015
# 1  2014-09-18  456.859985  456.859985  413.104004  424.440002  424.440002
# 2  2014-09-19  424.102997  427.834991  384.532013  394.795990  394.795990
# 3  2014-09-20  394.673004  423.295990  389.882996  408.903992  408.903992
# 4  2014-09-21  408.084991  412.425995  393.181000  398.821014  398.821014
#
#      Volume
# 0  21056800
# 1  34483200
# 2  37919700
# 3  36863600
# 4  26580100

# %%
data['Date'] = pd.to_datetime(data['Date'])

# %%
data['Year'] = data['Date'].dt.strftime('%Y')
data['Month'] = data['Date'].dt.strftime('%m')
data['Day'] = data['Date'].dt.strftime('%d')

# %%
a = ['Open', 'Close', 'Low', 'High', 'Year', 'Month']
b = data[a].groupby(['Year', 'Month']).sum()
b
# Out:
#                     Open         Close           Low          High
# Year Month
# 2014 09     5.777156e+03  5.700554e+03  5.574445e+03  5.895462e+03
#      10     1.133819e+04  1.128862e+04  1.100056e+04  1.160374e+04
#      11     1.094551e+04  1.098299e+04  1.071725e+04  1.129483e+04
#      12     1.063532e+04  1.057930e+04  1.043354e+04  1.077210e+04
# 2015 01     7.805797e+03  7.712259e+03  7.455362e+03  8.103139e+03
# ...                  ...           ...           ...           ...
# 2021 11     1.825726e+06  1.818645e+06  1.778706e+06  1.861402e+06
#      12     1.539783e+06  1.527159e+06  1.491356e+06  1.572397e+06
# 2022 01     1.282410e+06  1.274547e+06  1.245459e+06  1.303369e+06
#      02     1.136551e+06  1.141377e+06  1.109852e+06  1.167204e+06
#      03     1.021261e+06  1.022484e+06  1.000217e+06  1.043014e+06
#
# [91 rows x 4 columns]

# %%
b.plot(figsize=(20, 10), grid=True, marker='*')
plt.show()

# %%
b.plot(kind='bar', figsize=(18, 9))
plt.show()

# %%
b.plot(kind='area', figsize=(18, 9))
plt.show()
